# %%
import pandas as pd

# %%
results = pd.DataFrame({
    "Model": [
        "Ridge",
        "Lasso",
        "Random Forest",
        "XGBoost"
    ],
    "RMSE": [
        0.11525,
        0.11359,
        0.13802,
        0.11963
    ]
})

results
# Out:
#            Model     RMSE
# 0          Ridge  0.11525
# 1          Lasso  0.11359
# 2  Random Forest  0.13802
# 3        XGBoost  0.11963

# %%
results = results.sort_values(
    by="RMSE",
    ascending=True
)

results
# Out:
#            Model     RMSE
# 1          Lasso  0.11359
# 0          Ridge  0.11525
# 3        XGBoost  0.11963
# 2  Random Forest  0.13802

# %%
best_model = results.iloc[0]

print(
    f"最佳模型：{best_model['Model']}"
)

print(
    f"RMSE：{best_model['RMSE']:.5f}"
)
# Out:
# 最佳模型：Lasso
# RMSE：0.11359

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(
    results["Model"],
    results["RMSE"]
)

plt.title("Model Comparison")
plt.ylabel("RMSE")

plt.show()
